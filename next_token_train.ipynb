# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

# %%
# %cd /content/drive/Othercomputers/YizMac/MasterYear1/Projects/Next_Token_apr2024/
# Out:
# /content/drive/Othercomputers/YizMac/MasterYear1/Projects/Next_Token_apr2024

# %%
# !ldconfig -p | grep libcuda
# Out:
# 	libcudart.so.12 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcudart.so.12
# 	libcudart.so (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcudart.so

# %%
# !python train_gpu.py
# Out:
# Dataset m: 403
# Dataset n: 5110
# Dataset entropy: 1.6156
# Next Token vocab size: 104
# d_decode: 64
# Initializing a new transformer model from scratch
# Total trainable parameters: 273600 for 4 layer Transformer pos off model
# 0 | loss 4.4833 | entropy 1.6156
# 1 | loss 4.0744 | entropy 1.6156
# 10 | loss 2.5249 | entropy 1.6156
# 100 | loss 1.6767 | entropy 1.6156
# 500 | loss 1.6603 | entropy 1.6156
# 1000 | loss 1.6508 | entropy 1.6156
# 2000 | loss 1.6388 | entropy 1.6156
# 3000 | loss 1.6320 | entropy 1.6156
# 4000 | loss 1.6279 | entropy 1.6156
# 5000 | loss 1.6254 | entropy 1.6156
# 6000 | loss 1.6236 | entropy 1.6156
# 7000 | loss 1.6224 | entropy 1.6156
# 8000 | loss 1.6215 | entropy 1.6156
# 9000 | loss 1.6208 | entropy 1.6156
# Computing Lmm with cvxpy
# ...
#                                      CVXPY
#                                      v1.3.4
# ...
# (CVXPY) May 26 04:40:11 AM: Your problem has 41912 variables, 41509 constraints, and 0 parameters.
# ...

# %%
# !zip -r results_tiny_extract_m404 zips
